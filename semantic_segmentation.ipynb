# %% [markdown]
# <a href="https://colab.research.google.com/github/seydanur-hemithea/COMPUTER_V-S-ON-/blob/main/semantic_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets

# %%
# !pip install pycocotools opencv-python matplotlib

# %%
from pycocotools.coco import COCO
import cv2
import matplotlib.pyplot as plt

# %%
from datasets import load_dataset

dataset = load_dataset("peteole/coco2017-segmentation-10k-256x256")

# %%
import matplotlib.pyplot as plt
import numpy as np

sample = dataset["train"][0]
image = np.array(sample["image"])
mask = np.array(sample["segmentation"])

colored_mask = np.zeros_like(image)

# class 1 is green
colored_mask[mask == 1] = [0, 255, 0]

# visual+mask
blended = cv2.addWeighted(image, 0.7, colored_mask, 0.3, 0)

import matplotlib.pyplot as plt

plt.imshow(blended)
plt.axis('off')
plt.title("Segmentation")
plt.show()
