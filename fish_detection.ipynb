# %% [markdown]
# <a href="https://colab.research.google.com/github/seydanur-hemithea/COMPUTER_V-S-ON-/blob/main/fish_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 40.1 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow
from roboflow import Roboflow

rf = Roboflow(api_key="your-roboflow_api_key")
project = rf.workspace("object-detection-assignement").project("fish-detection-unwou")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.8/89.8 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 89.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 26.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # hızlı ve hafif model
model.train(data="/content/Fish-Detection-1/data.yaml", epochs=30, imgsz=640)
# Out:
# ...
# Ultralytics 8.3.206 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7cc378be-8b9b-4d6e-a29b-f39fdfe29292" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7cc378be-8b9b-4d6e-a29b-f39fdfe29292">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model.predict(source="balik.jpg", save=True, save_txt=True)
# Out:
# image 1/1 /content/balik.jpg: 448x640 2 0s, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict2
# 1 label saved to /content/runs/detect/predict2/labels

# %%
results = model.predict(source="balik.jpg", save=True, save_txt=True)

for r in results:
    boxes = r.boxes
    for box in boxes:
        print(box.xyxy, box.conf, box.cls)
# Out:
# image 1/1 /content/balik.jpg: 448x640 2 0s, 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict
# 1 label saved to /content/runs/detect/predict/labels
# tensor([[  0.3141,  20.9859, 268.5410, 121.1503]], device='cuda:0') tensor([0.6819], device='cuda:0') tensor([0.], device='cuda:0')
# tensor([[ 43.4774,  36.9060, 264.5362, 119.7139]], device='cuda:0') tensor([0.4335], device='cuda:0') tensor([0.], device='cuda:0')

# %%
import os
os.listdir('/content/runs/detect/predict')
# Out:
# ['balik.jpg']

# %%
# !ls /content/runs/detect
# Out:
# predict  predict2  train

# %%
import os
os.listdir('/content/runs/detect/predict')
os.listdir('/content/runs/detect/predict2')
# Out:
# ['balik.jpg', 'labels']

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/predict2/balik.jpg')
